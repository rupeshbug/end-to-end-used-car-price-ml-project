# %% [markdown]
# ## Used Car Price Prediction

# %% [markdown]
# ### Import relevant libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import re
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load and Explore the data

# %%
pd.set_option('display.max_rows', None)        # Show all rows
pd.set_option('display.max_columns', None)     # Show all columns
pd.set_option('display.width', None)           # Don’t wrap lines
pd.set_option('display.max_colwidth', None)    # Don’t truncate column content

# %%
df = pd.read_csv('data/used_cars.csv')

# %%
df.head()
# Out:
#       brand                            model  model_year      milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51,000 mi.
# 1   Hyundai                     Palisade SEL        2021  34,742 mi.
# 2     Lexus                    RX 350 RX 350        2022  22,372 mi.
# 3  INFINITI                 Q50 Hybrid Sport        2015  88,900 mi.
# 4      Audi        Q3 45 S line Premium Plus        2021   9,835 mi.
#
#        fuel_type                                             engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...
# 1       Gasoline                               3.8L V6 24V GDI DOHC
# 2       Gasoline                                     3.5 Liter DOHC
# 3         Hybrid  354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# 4       Gasoline                         2.0L I4 16V GDI DOHC Turbo
#
#         transmission                 ext_col int_col  \
# 0        6-Speed A/T                   Black   Black
# 1  8-Speed Automatic         Moonlight Cloud    Gray
# 2          Automatic                    Blue   Black
# 3        7-Speed A/T                   Black   Black
# 4  8-Speed Automatic  Glacier White Metallic   Black
#
#                                  accident clean_title    price
# 0  At least 1 accident or damage reported         Yes  $10,300
# 1  At least 1 accident or damage reported         Yes  $38,005
# 2                           None reported         NaN  $54,598
# 3                           None reported         Yes  $15,500
# 4                           None reported         NaN  $34,999

# %%
df.shape
# Out:
# (4009, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4009 entries, 0 to 4008
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         4009 non-null   object
#  1   model         4009 non-null   object
#  2   model_year    4009 non-null   int64
#  3   milage        4009 non-null   object
#  4   fuel_type     3839 non-null   object
#  5   engine        4009 non-null   object
#  6   transmission  4009 non-null   object
#  7   ext_col       4009 non-null   object
#  8   int_col       4009 non-null   object
#  9   accident      3896 non-null   object
#  10  clean_title   3413 non-null   object
#  11  price         4009 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 376.0+ KB

# %% [markdown]
# ### Data Cleaning

# %%
df.isnull().sum()
# Out:
# brand             0
# model             0
# model_year        0
# milage            0
# fuel_type       170
# engine            0
# transmission      0
# ext_col           0
# int_col           0
# accident        113
# clean_title     596
# price             0
# dtype: int64

# %% [markdown]
# fuel_type, accident, clean_title are three columns with null/missing values.

# %%
df['clean_title'].value_counts(dropna=False)
# Out:
# clean_title
# Yes    3413
# NaN     596
# Name: count, dtype: int64

# %% [markdown]
# Upon inspection, the clean_title column contains only one unique value — "Yes" — with around 15% missing values. Since this feature shows no variance (i.e., all values are the same), it provides no predictive power to the model. Therefore, we can safely drop this column to simplify the dataset without losing any meaningful information.

# %%
df.drop(columns=['clean_title'], inplace=True)

# %%
df.head()
# Out:
#       brand                            model  model_year      milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51,000 mi.
# 1   Hyundai                     Palisade SEL        2021  34,742 mi.
# 2     Lexus                    RX 350 RX 350        2022  22,372 mi.
# 3  INFINITI                 Q50 Hybrid Sport        2015  88,900 mi.
# 4      Audi        Q3 45 S line Premium Plus        2021   9,835 mi.
#
#        fuel_type                                                engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capability
# 1       Gasoline                                  3.8L V6 24V GDI DOHC
# 2       Gasoline                                        3.5 Liter DOHC
# 3         Hybrid   354.0HP 3.5L V6 Cylinder Engine Gas/Electric Hybrid
# 4       Gasoline                            2.0L I4 16V GDI DOHC Turbo
#
#         transmission                 ext_col int_col  \
# 0        6-Speed A/T                   Black   Black
# 1  8-Speed Automatic         Moonlight Cloud    Gray
# 2          Automatic                    Blue   Black
# 3        7-Speed A/T                   Black   Black
# 4  8-Speed Automatic  Glacier White Metallic   Black
#
#                                  accident    price
# 0  At least 1 accident or damage reported  $10,300
# 1  At least 1 accident or damage reported  $38,005
# 2                           None reported  $54,598
# 3                           None reported  $15,500
# 4                           None reported  $34,999

# %%
# Mode imputation for fuel_type and accident columns

df['fuel_type'].fillna(df['fuel_type'].mode()[0], inplace=True)
df['accident'].fillna(df['accident'].mode()[0], inplace=True)

# %%
df.head()
# Out:
#       brand                            model  model_year      milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51,000 mi.
# 1   Hyundai                     Palisade SEL        2021  34,742 mi.
# 2     Lexus                    RX 350 RX 350        2022  22,372 mi.
# 3  INFINITI                 Q50 Hybrid Sport        2015  88,900 mi.
# 4      Audi        Q3 45 S line Premium Plus        2021   9,835 mi.
#
#        fuel_type                                                engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capability
# 1       Gasoline                                  3.8L V6 24V GDI DOHC
# 2       Gasoline                                        3.5 Liter DOHC
# 3         Hybrid   354.0HP 3.5L V6 Cylinder Engine Gas/Electric Hybrid
# 4       Gasoline                            2.0L I4 16V GDI DOHC Turbo
#
#         transmission                 ext_col int_col  \
# 0        6-Speed A/T                   Black   Black
# 1  8-Speed Automatic         Moonlight Cloud    Gray
# 2          Automatic                    Blue   Black
# 3        7-Speed A/T                   Black   Black
# 4  8-Speed Automatic  Glacier White Metallic   Black
#
#                                  accident    price
# 0  At least 1 accident or damage reported  $10,300
# 1  At least 1 accident or damage reported  $38,005
# 2                           None reported  $54,598
# 3                           None reported  $15,500
# 4                           None reported  $34,999

# %%
df.isnull().sum()
# Out:
# brand           0
# model           0
# model_year      0
# milage          0
# fuel_type       0
# engine          0
# transmission    0
# ext_col         0
# int_col         0
# accident        0
# price           0
# dtype: int64

# %%
# check for duplicate rows
df.duplicated().sum()
# Out:
# 0

# %%
# convert data types

df['milage'] = (
    df['milage']
    .str.replace('mi.', '', regex=False)  # remove the unit
    .str.replace(',', '', regex=False)   # remove commas
    .astype(float)                       # convert to float
)
df['price'] = df['price'].str.replace('$', '').str.replace(',', '').astype(float)

# %%
df.head()
# Out:
#       brand                            model  model_year   milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51000.0
# 1   Hyundai                     Palisade SEL        2021  34742.0
# 2     Lexus                    RX 350 RX 350        2022  22372.0
# 3  INFINITI                 Q50 Hybrid Sport        2015  88900.0
# 4      Audi        Q3 45 S line Premium Plus        2021   9835.0
#
#        fuel_type                                                engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capability
# 1       Gasoline                                  3.8L V6 24V GDI DOHC
# 2       Gasoline                                        3.5 Liter DOHC
# 3         Hybrid   354.0HP 3.5L V6 Cylinder Engine Gas/Electric Hybrid
# 4       Gasoline                            2.0L I4 16V GDI DOHC Turbo
#
#         transmission                 ext_col int_col  \
# 0        6-Speed A/T                   Black   Black
# 1  8-Speed Automatic         Moonlight Cloud    Gray
# 2          Automatic                    Blue   Black
# 3        7-Speed A/T                   Black   Black
# 4  8-Speed Automatic  Glacier White Metallic   Black
#
#                                  accident    price
# 0  At least 1 accident or damage reported  10300.0
# 1  At least 1 accident or damage reported  38005.0
# 2                           None reported  54598.0
# 3                           None reported  15500.0
# 4                           None reported  34999.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4009 entries, 0 to 4008
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         4009 non-null   object
#  1   model         4009 non-null   object
#  2   model_year    4009 non-null   int64
#  3   milage        4009 non-null   float64
#  4   fuel_type     4009 non-null   object
#  5   engine        4009 non-null   object
#  6   transmission  4009 non-null   object
#  7   ext_col       4009 non-null   object
#  8   int_col       4009 non-null   object
#  9   accident      4009 non-null   object
#  10  price         4009 non-null   float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 344.6+ KB

# %% [markdown]
# #### Engine feature extraction and cleaning
#
# The engine column contains mixed, semi-structured information — including horsepower (HP), engine displacement (e.g., “3.5L”), cylinder type, and fuel type.
# Among these, horsepower and engine capacity (in liters) are the most meaningful and consistently useful indicators of a vehicle’s performance and price.
# Higher horsepower and larger engines generally correlate with higher vehicle prices.

# %%
df['engine']
# Out:
# 0                        300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capability
# 1                                                        3.8L V6 24V GDI DOHC
# 2                                                              3.5 Liter DOHC
# 3                         354.0HP 3.5L V6 Cylinder Engine Gas/Electric Hybrid
# 4                                                  2.0L I4 16V GDI DOHC Turbo
# 5                                                                   2.4 Liter
# 6                                292.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 7                                282.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 8                               311.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 9                                 534.0HP Electric Motor Electric Fuel System
# 10                                                                         V6
# 11                              715.0HP 5.2L 12 Cylinder Engine Gasoline Fuel
# 12                      382.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 13                              400.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 14                                                     2.0 Liter Supercharged
# 15                               375.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 16                                                 2.0L I4 16V GDI DOHC Turbo
# 17                              305.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 18                              287.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 19                               550.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 20                              375.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 21                        120.0HP 2.2L 4 Cylinder Engine Flex Fuel Capability
# 22                                                            3.0 Liter Turbo
# 23                                            3.5L V6 24V PDI DOHC Twin Turbo
# 24                               355.0HP 5.3L 8 Cylinder Engine Gasoline Fuel
# 25                               276.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 26                                                                  1.8 Liter
# 27                               382.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 28                               445.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 29                                   2.0L I4 16V GDI DOHC Turbo Flexible Fuel
# 30                              362.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 31                               345.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 32                                                                     120 AH
# 33                              276.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 34                               383.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 35                               180.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# 36                                                            3.0 Liter Turbo
# 37                               211.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 38                              173.0HP 2.7L V6 Cylinder Engine Gasoline Fuel
# 39                               240.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 40                       552.0HP 6.0L 12 Cylinder Engine Flex Fuel Capability
# 41                                                             3.5 Liter SOHC
# 42                                        3.0L V6 Cylinder Engine Diesel Fuel
# 43                                                  4.4 Liter DOHC Twin Turbo
# 44                                536.0HP Electric Motor Electric Fuel System
# 45                              310.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 46                                                        5.3L V8 16V GDI OHV
# 47                               228.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 48                              268.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 49                              300.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 50                               503.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 51                                                       2.4L I4 16V GDI DOHC
# 52                               325.0HP 6.0L 8 Cylinder Engine Gasoline Fuel
# 53                          400.0HP 3.8L Flat 6 Cylinder Engine Gasoline Fuel
# 54                               208.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 55                              250.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 56                                                 1.5L I3 12V GDI DOHC Turbo
# 57                               200.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 58                               420.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 59                              300.0HP 3.7L V6 Cylinder Engine Gasoline Fuel
# 60                        400.0HP 2.0L 4 Cylinder Engine Plug-In Electric/Gas
# 61                                                      5.2L V10 40V PDI DOHC
# 62                              302.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 63                                                                  2.0 Liter
# 64                              306.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 65      382.0HP 3.0L Straight 6 Cylinder Engine Gasoline/Mild Electric Hybrid
# 66                                                       3.0 Liter DOHC Turbo
# 67                               237.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 68                                536.0HP Electric Motor Electric Fuel System
# 69                               248.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 70                               425.0HP 6.1L 8 Cylinder Engine Gasoline Fuel
# 71                              582.0HP 6.0L 12 Cylinder Engine Gasoline Fuel
# 72                      425.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 73                               300.0HP 1.6L 3 Cylinder Engine Gasoline Fuel
# 74                              444.0HP 2.9L V6 Cylinder Engine Gasoline Fuel
# 75                              335.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 76           5.2L V-10 gasoline direct injection, DOHC, variable valve contro
# 77                              424.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 78                              340.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 79                              225.0HP 3.3L V6 Cylinder Engine Gasoline Fuel
# 80                                                                  2.0 Liter
# 81                          340.0HP 3.4L Flat 6 Cylinder Engine Gasoline Fuel
# 82                              365.0HP 3.3L V6 Cylinder Engine Gasoline Fuel
# 83                               315.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 84                         199.0HP 2.4L 4 Cylinder Engine Gas/Electric Hybrid
# 85                               560.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 86                      326.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 87      362.0HP 3.0L Straight 6 Cylinder Engine Gasoline/Mild Electric Hybrid
# 88                               560.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 89                               165.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 90                               276.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 91                                                1.6L I4 16V GDI DOHC Hybrid
# 92                                835.0HP Electric Motor Electric Fuel System
# 93                                           5.2L V12 48V GDI DOHC Twin Turbo
# 94                               241.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 95                      300.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 96                                                       5.7L V8 16V MPFI OHV
# 97                              306.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 98                      215.0HP 2.5L Straight 6 Cylinder Engine Gasoline Fuel
# 99                               130.0HP 1.8L 4 Cylinder Engine Gasoline Fuel
# 100                                          6.2L V8 16V GDI OHV Supercharged
# 101                             288.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 102                                                      5.0L V8 32V PDI DOHC
# 103                       369.0HP 1.5L 3 Cylinder Engine Plug-In Electric/Gas
# 104                        200.0HP 2.5L 4 Cylinder Engine Gas/Electric Hybrid
# 105                                           3.0L V6 24V GDI DOHC Twin Turbo
# 106                                                           2.0 Liter Turbo
# 107                             195.0HP 4.3L V6 Cylinder Engine Gasoline Fuel
# 108                             285.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 109                              240.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 110                             340.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 111                              237.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 112                                                      4.4 Liter Twin Turbo
# 113                             400.0HP 6.75L 8 Cylinder Engine Gasoline Fuel
# 114                                                            3.0 Liter GTDI
# 115                              550.0HP 5.5L 8 Cylinder Engine Gasoline Fuel
# 116                                                     3.6L V6 24V MPFI DOHC
# 117                      300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capability
# 118                              211.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 119                             485.0HP 3.8L V6 Cylinder Engine Gasoline Fuel
# 120                                                                        V6
# 121                              132.0HP 1.8L 4 Cylinder Engine Gasoline Fuel
# 122                               835.0HP Electric Motor Electric Fuel System
# 123                                                           2.0 Liter Turbo
# 124                      416.0HP 3.0L V6 Cylinder Engine Plug-In Electric/Gas
# 125                                        5.3L V8 16V MPFI OHV Flexible Fuel
# 126                       360.0HP 3.5L V6 Cylinder Engine Gas/Electric Hybrid
# 127                                                           3.0 Liter Turbo
# 128                             280.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 129                               620.0HP Electric Motor Electric Fuel System
# 130                                                                         –
# 131                              265.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 132                              445.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 133                                                      2.5L H4 16V GDI DOHC
# 134                              469.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 135                              300.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 136                                                      3.0 Liter Twin Turbo
# 137                              169.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 138                              383.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 139                         400.0HP 3.8L Flat 6 Cylinder Engine Gasoline Fuel
# 140                              330.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 141                              400.0HP 5.6L 8 Cylinder Engine Gasoline Fuel
# 142                         275.0HP 2.7L Flat 6 Cylinder Engine Gasoline Fuel
# 143                                                           3.0 Liter Turbo
# 144                              303.0HP 5.3L 8 Cylinder Engine Gasoline Fuel
# 145                              560.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 146                                                2.0L I4 16V GDI DOHC Turbo
# 147                             240.0HP 3.8L V6 Cylinder Engine Gasoline Fuel
# 148                              240.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 149                              450.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 150                             288.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 151                                                2.0L I4 16V GDI SOHC Turbo
# 152                             651.0HP 6.3L 12 Cylinder Engine Gasoline Fuel
# 153                              420.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 154                       255.0HP 5.4L 8 Cylinder Engine Flex Fuel Capability
# 155                               455.0HP Electric Motor Electric Fuel System
# 156                                                     4.0L V6 24V MPFI DOHC
# 157                              182.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 158                             300.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 159                             236.0HP 4.0L V6 Cylinder Engine Gasoline Fuel
# 160                       370.0HP 6.7L Straight 6 Cylinder Engine Diesel Fuel
# 161                                                      2.4L I4 16V GDI DOHC
# 162                              275.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# 163                     212.0HP 4.5L Straight 6 Cylinder Engine Gasoline Fuel
# 164                             565.0HP 3.8L V6 Cylinder Engine Gasoline Fuel
# 165                                                                 2.4 Liter
# 166                              248.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 167                              230.0HP 4.7L 8 Cylinder Engine Gasoline Fuel
# 168                                                1.5L I4 16V GDI DOHC Turbo
# 169                              171.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 170                              360.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# 171                             400.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 172                             252.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 173                                           4.0L V8 32V GDI DOHC Twin Turbo
# 174                              220.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 175                                                2.0L I4 16V GDI DOHC Turbo
# 176                                                1.3L I3 12V GDI DOHC Turbo
# 177                              180.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 178                        188.0HP 2.0L 4 Cylinder Engine Gas/Electric Hybrid
# 179                      275.0HP 3.7L V6 Cylinder Engine Flex Fuel Capability
# 180                                           3.8L H6 24V GDI DOHC Twin Turbo
# 181                                                2.3L I4 16V GDI DOHC Turbo
# 182                     235.0HP 3.2L Straight 6 Cylinder Engine Gasoline Fuel
# 183                       320.0HP 5.3L 8 Cylinder Engine Flex Fuel Capability
# 184                              400.0HP 2.5L 5 Cylinder Engine Gasoline Fuel
# 185                              300.0HP 5.4L 8 Cylinder Engine Gasoline Fuel
# 186                              138.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 187                             354.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 188                              291.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 189                               455.0HP Electric Motor Electric Fuel System
# 190                             523.0HP 6.0L 12 Cylinder Engine Gasoline Fuel
# 191                             565.0HP 3.8L V6 Cylinder Engine Gasoline Fuel
# 192                                                      4.7 Liter Twin Turbo
# 193                                                      3.6L V6 24V GDI DOHC
# 194                                                2.5L I4 16V GDI DOHC Turbo
# 195                             440.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 196                                                      5.6L V8 32V GDI DOHC
# 197                              383.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 198                             310.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 199                               188.0HP 3.0L V6 Cylinder Engine Diesel Fuel
# 200                     225.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 201                              181.0HP 1.5L 4 Cylinder Engine Gasoline Fuel
# 202                              240.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 203                                                         5.4 Liter SC DOHC
# 204                              420.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 205                                                      5.0L V8 32V PDI DOHC
# 206                                        5.8L V8 32V MPFI DOHC Supercharged
# 207                              173.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# 208                                           4.0L V8 32V GDI DOHC Twin Turbo
# 209                                                                 5.7 Liter
# 210                              429.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# 211                         355.0HP 3.8L Flat 6 Cylinder Engine Gasoline Fuel
# 212                              375.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 213                             263.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 214                     320.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 215                              237.0HP 2.2L 4 Cylinder Engine Gasoline Fuel
# 216                                                           1.5 Liter Turbo
# 217                             310.0HP 6.8L 10 Cylinder Engine Gasoline Fuel
# 218                              302.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 219                              382.0HP 5.5L 8 Cylinder Engine Gasoline Fuel
# 220                             306.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 221                              210.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 222                                                      6.4L V8 16V MPFI OHV
# 223                             450.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 224                             404.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 225                               670.0HP Electric Motor Electric Fuel System
# 226                              563.0HP 5.5L 8 Cylinder Engine Gasoline Fuel
# 227                                                            3.5 Liter GTDI
# 228                             283.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 229                                          8.0L W16 64V GDI DOHC Twin Turbo
# 230                                                      3.5L V6 24V PDI DOHC
# 231                                                     2.0L I4 16V MPFI DOHC
# 232                                                     3.6L V6 24V MPFI DOHC
# 233                              400.0HP 4.2L 8 Cylinder Engine Gasoline Fuel
# 234                              150.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 235                              560.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 236                                                                  Electric
# 237                     300.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 238                         325.0HP 3.4L Flat 6 Cylinder Engine Gasoline Fuel
# 239                       266.0HP 2.5L 4 Cylinder Engine Plug-In Electric/Gas
# 240                              275.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# 241                             335.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 242                              355.0HP 5.3L 8 Cylinder Engine Gasoline Fuel
# 243                             328.0HP 3.7L V6 Cylinder Engine Gasoline Fuel
# 244                             310.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 245                             304.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 246                              375.0HP 5.6L 8 Cylinder Engine Gasoline Fuel
# 247                             362.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 248                              381.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 249                              381.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 250                             280.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 251                             493.0HP 5.0L 10 Cylinder Engine Gasoline Fuel
# 252                             263.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 253                               355.0HP Electric Motor Electric Fuel System
# 254          5.2L V-10 gasoline direct injection, DOHC, variable valve contro
# 255                                           2.9L V6 24V GDI DOHC Twin Turbo
# 256                                                1.2L I3 12V GDI DOHC Turbo
# 257                                                                         –
# 258                              641.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 259                             328.0HP 3.7L V6 Cylinder Engine Gasoline Fuel
# 260                             424.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 261                                                      3.5L V6 24V PDI DOHC
# 262                                                                 5.6 Liter
# 263                                                            2.0 Liter TFSI
# 264                              760.0HP 5.2L 8 Cylinder Engine Gasoline Fuel
# 265                             450.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 266                               329.0HP Electric Motor Electric Fuel System
# 267                                                      5.7L V8 16V MPFI OHV
# 268                              239.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# 269                                                      2.0 Liter DOHC Turbo
# 270                                               2.5L I4 16V PDI DOHC Hybrid
# 271                              160.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# 272                              402.0HP 4.7L 8 Cylinder Engine Gasoline Fuel
# 273                              166.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 274                              300.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 275                             275.0HP 3.7L V6 Cylinder Engine Gasoline Fuel
# 276                                                2.0L I4 16V GDI DOHC Turbo
# 277                             328.0HP 3.7L V6 Cylinder Engine Gasoline Fuel
# 278                              390.0HP 5.6L 8 Cylinder Engine Gasoline Fuel
# 279             444.0HP 2.9L V6 Cylinder Engine Gasoline/Mild Electric Hybrid
# 280                                                                 3.0 Liter
# 281                                210.0HP 2.0L 4 Cylinder Engine Diesel Fuel
# 282                             330.0HP 3.7L V6 Cylinder Engine Gasoline Fuel
# 283                             285.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 284                             265.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 285                                           3.0L H6 24V GDI DOHC Twin Turbo
# 286                             362.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 287                         275.0HP 2.7L Flat 6 Cylinder Engine Gasoline Fuel
# 288                             300.0HP 3.7L V6 Cylinder Engine Gasoline Fuel
# 289                              292.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 290                              147.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 291                                                      4.4 Liter Twin Turbo
# 292                                                2.0L I4 16V GDI DOHC Turbo
# 293                       357.0HP 1.5L 3 Cylinder Engine Plug-In Electric/Gas
# 294                                                      3.5L V6 24V PDI DOHC
# 295                                                               2.5L I4 16V
# 296                                                      3.6L V6 24V GDI DOHC
# 297                             400.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 298                               271.0HP Electric Motor Electric Fuel System
# 299                              350.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 300                              400.0HP 6.0L 8 Cylinder Engine Gasoline Fuel
# 301                              200.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 302                              611.0HP 3.9L 8 Cylinder Engine Gasoline Fuel
# 303                         295.0HP 3.4L Flat 6 Cylinder Engine Gasoline Fuel
# 304                                                     6.8L V12 48V GDI DOHC
# 305                                           4.0L V8 32V GDI DOHC Twin Turbo
# 306              603.0HP 4.0L 8 Cylinder Engine Gasoline/Mild Electric Hybrid
# 307                             280.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 308                              302.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 309                              235.0HP 4.7L 8 Cylinder Engine Gasoline Fuel
# 310                              235.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 311                             210.0HP 3.7L V6 Cylinder Engine Gasoline Fuel
# 312                                           3.0L V6 24V GDI DOHC Twin Turbo
# 313                                                                 2.0 Liter
# 314                                           4.0L V8 32V GDI DOHC Twin Turbo
# 315                                                2.0L I4 16V GDI DOHC Turbo
# 316                                                2.3L I4 16V GDI DOHC Turbo
# 317                              469.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 318                              228.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# 319                     315.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 320                             365.0HP 3.3L V6 Cylinder Engine Gasoline Fuel
# 321                                                                  Electric
# 322                              210.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 323                                                      2.5L I4 16V PDI DOHC
# 324                     425.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 325                              429.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 326          AMG 3L I-6 gasoline direct injection, DOHC, variable valve contr
# 327                              523.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 328                              305.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 329                                                      4.0 Liter Twin Turbo
# 330                                                2.5L I4 16V GDI DOHC Turbo
# 331                              132.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 332                                           4.0L V8 32V GDI DOHC Twin Turbo
# 333                                                                 3.0 Liter
# 334                                                      3.8L V6 24V GDI DOHC
# 335                              454.0HP 4.7L 8 Cylinder Engine Gasoline Fuel
# 336                                                           2.0 Liter Turbo
# 337                              420.0HP 5.6L 8 Cylinder Engine Gasoline Fuel
# 338                                                                         –
# 339                              490.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 340                                                            2.0 Liter TFSI
# 341                              301.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# 342                              240.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 343                              280.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 344                              395.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 345                     425.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 346                               670.0HP Electric Motor Electric Fuel System
# 347                              250.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 348                              300.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 349                                                           3.0 Liter Turbo
# 350                              272.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 351                                                2.0L I4 16V GDI DOHC Turbo
# 352                              420.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 353                             268.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 354                                                                 4.4 Liter
# 355          1.6L I-4 gasoline direct injection, DOHC, variable valve control
# 356                                                      3.5L V6 24V PDI DOHC
# 357                               188.0HP 3.0L V6 Cylinder Engine Diesel Fuel
# 358                              228.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 359                             550.0HP 5.2L 10 Cylinder Engine Gasoline Fuel
# 360                              292.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 361                       437.0HP 3.4L V6 Cylinder Engine Gas/Electric Hybrid
# 362                                                3.0L V6 24V GDI DOHC Turbo
# 363                              252.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 364                                                     5.2L V10 40V GDI DOHC
# 365                     230.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 366                             354.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 367                                         3.0L I6 24V DDI DOHC Turbo Diesel
# 368                     320.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 369                                                      3.8L V6 24V GDI DOHC
# 370                              323.0HP 6.0L 8 Cylinder Engine Gasoline Fuel
# 371                                                      2.5L I4 16V GDI DOHC
# 372                                                           2.0 Liter Turbo
# 373                              211.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 374                         256.0HP 3.6L Flat 6 Cylinder Engine Gasoline Fuel
# 375                              140.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# 376                                                      2.5L I4 16V PDI DOHC
# 377                              600.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 378                              390.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 379                       188.0HP 2.0L 4 Cylinder Engine Plug-In Electric/Gas
# 380                       437.0HP 3.4L V6 Cylinder Engine Gas/Electric Hybrid
# 381                              240.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 382                       310.0HP 5.4L 8 Cylinder Engine Flex Fuel Capability
# 383                                                    Standard Range Battery
# 384                               188.0HP 3.0L V6 Cylinder Engine Diesel Fuel
# 385                              603.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 386                     320.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 387                              140.0HP 1.8L 4 Cylinder Engine Gasoline Fuel
# 388                                         3.0L V6 24V GDI DOHC Supercharged
# 389                              560.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 390                                                             2.0 Liter TSI
# 391                             409.0HP 3.4L V6 Cylinder Engine Gasoline Fuel
# 392                             328.0HP 3.7L V6 Cylinder Engine Gasoline Fuel
# 393                     215.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 394                              560.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 395                                                           3.0 Liter Turbo
# 396                                                      2.4L I4 16V GDI DOHC
# 397                               835.0HP Electric Motor Electric Fuel System
# 398                              240.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 399                              640.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 400                              169.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 401                              550.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 402                             204.0HP 2.5L V6 Cylinder Engine Gasoline Fuel
# 403     375.0HP 3.0L Straight 6 Cylinder Engine Gasoline/Mild Electric Hybrid
# 404                              316.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 405                             173.0HP 2.7L V6 Cylinder Engine Gasoline Fuel
# 406                                                     3.6L V6 24V MPFI DOHC
# 407                             362.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 408                                                       5.3L V8 16V GDI OHV
# 409                              591.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 410                               835.0HP Electric Motor Electric Fuel System
# 411                        219.0HP 2.5L 4 Cylinder Engine Gas/Electric Hybrid
# 412                             505.0HP 2.9L V6 Cylinder Engine Gasoline Fuel
# 413                                                                 2.0 Liter
# 414                                                2.0L I4 16V GDI SOHC Turbo
# 415                              403.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 416                                       6.2L V8 16V MPFI SOHC Flexible Fuel
# 417                             287.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 418                              170.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 419                              115.0HP 1.7L 4 Cylinder Engine Gasoline Fuel
# 420                              562.0HP 3.8L 8 Cylinder Engine Gasoline Fuel
# 421                             404.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 422          HEMI 5.7L V-8 variable valve control, regular unleaded, engine w
# 423                             404.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 424                             220.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 425                              302.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# 426                       169.0HP 2.5L 4 Cylinder Engine Flex Fuel Capability
# 427                                                       3.6 Liter SIDI DOHC
# 428                             365.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 429                              106.0HP 1.5L 4 Cylinder Engine Gasoline Fuel
# 430                              603.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 431                                                 3.0 Liter DOHC Twin Turbo
# 432                              416.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 433                              201.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 434                                                     4.0L V6 24V MPFI DOHC
# 435              496.0HP 4.0L 8 Cylinder Engine Gasoline/Mild Electric Hybrid
# 436                                           4.0L V8 32V GDI DOHC Twin Turbo
# 437                              140.0HP 1.8L 4 Cylinder Engine Gasoline Fuel
# 438                             362.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 439                              505.0HP 7.0L 8 Cylinder Engine Gasoline Fuel
# 440                                475.0HP 6.7L 8 Cylinder Engine Diesel Fuel
# 441                              184.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 442                              407.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 443                     543.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 444                              301.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# 445                             333.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 446                              280.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 447                                                                 3.0 Liter
# 448                                                 4.4 Liter DOHC Twin Turbo
# 449                     425.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 450                             563.0HP 6.7L 12 Cylinder Engine Gasoline Fuel
# 451                               355.0HP Electric Motor Electric Fuel System
# 452                             204.0HP 2.5L V6 Cylinder Engine Gasoline Fuel
# 453                              240.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 454                              553.0HP 3.9L 8 Cylinder Engine Gasoline Fuel
# 455                              471.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 456                                       111.2Ah / FR 70kW / RR 160kW (697V)
# 457                              295.0HP 5.3L 8 Cylinder Engine Gasoline Fuel
# 458                             272.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 459                             350.0HP 3.7L V6 Cylinder Engine Gasoline Fuel
# 460                              345.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 461                             365.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 462                             325.0HP 3.7L V6 Cylinder Engine Gasoline Fuel
# 463                                           4.4L V8 32V GDI DOHC Twin Turbo
# 464                             380.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 465                              250.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 466                             340.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 467                                                1.5L I3 12V PDI DOHC Turbo
# 468                             140.0HP 2.8L V6 Cylinder Engine Gasoline Fuel
# 469                              550.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 470                                                                 2.0 Liter
# 471                                                      5.7L V8 16V MPFI OHV
# 472                               835.0HP Electric Motor Electric Fuel System
# 473          6.6L V-12 gasoline direct injection, DOHC, variable valve contro
# 474                              383.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 475                              247.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 476                                                            3.5 Liter SOHC
# 477                              471.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 478                             349.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 479                              247.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 480                                                      5.7L V8 16V MPFI OHV
# 481                                                3.0L V6 24V GDI DOHC Turbo
# 482                                                           4.0 Liter Turbo
# 483                              420.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 484                              503.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 485                              420.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 486                              190.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# 487                                          6.7L V12 48V GDI DOHC Twin Turbo
# 488                              420.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 489                                                2.0L I4 16V GDI DOHC Turbo
# 490                              228.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 491                                                                         –
# 492                       180.0HP 2.4L 4 Cylinder Engine Flex Fuel Capability
# 493                                           4.0L V8 32V GDI DOHC Twin Turbo
# 494                              410.0HP 6.4L 8 Cylinder Engine Gasoline Fuel
# 495                              208.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 496                                                                 2.0 Liter
# 497                              316.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 498                             375.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 499                       208.0HP 3.3L V6 Cylinder Engine Gas/Electric Hybrid
# 500                              282.0HP 4.7L 8 Cylinder Engine Gasoline Fuel
# 501                             310.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 502                                260.0HP 6.6L 8 Cylinder Engine Diesel Fuel
# 503                               200.0HP Electric Motor Electric Fuel System
# 504                                         2.0L I4 16V GDI DOHC Turbo Hybrid
# 505     375.0HP 3.0L Straight 6 Cylinder Engine Gasoline/Mild Electric Hybrid
# 506                                                3.0L I6 24V GDI DOHC Turbo
# 507                                                     5.7L V8 32V MPFI DOHC
# 508                              228.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 509                     300.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 510                              184.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 511                             340.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 512                              260.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 513                     184.0HP 2.5L Straight 6 Cylinder Engine Gasoline Fuel
# 514                       400.0HP 2.0L 4 Cylinder Engine Plug-In Electric/Gas
# 515                                                2.0L I4 16V GDI DOHC Turbo
# 516                                                   3.5L 24V SOHC I-VTEC V6
# 517                              420.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 518                               425.0HP Electric Motor Electric Fuel System
# 519                             302.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 520                                                      3.6L V6 24V GDI DOHC
# 521                              445.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 522                              300.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 523                              255.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 524                         245.0HP 2.7L Flat 6 Cylinder Engine Gasoline Fuel
# 525                                           3.5L V6 24V PDI DOHC Twin Turbo
# 526                               835.0HP Electric Motor Electric Fuel System
# 527                                                           2.0 Liter Turbo
# 528                              550.0HP 5.4L 8 Cylinder Engine Gasoline Fuel
# 529                               425.0HP Electric Motor Electric Fuel System
# 530                             332.0HP 3.7L V6 Cylinder Engine Gasoline Fuel
# 531                              381.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 532                              375.0HP 5.6L 8 Cylinder Engine Gasoline Fuel
# 533                              169.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 534                              400.0HP 5.6L 8 Cylinder Engine Gasoline Fuel
# 535                              380.0HP 4.3L 8 Cylinder Engine Gasoline Fuel
# 536                                                                 3.0 Liter
# 537                             400.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 538                              247.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 539                             261.0HP 4.0L V6 Cylinder Engine Gasoline Fuel
# 540                              370.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 541                                                1.3L I3 12V GDI DOHC Turbo
# 542                               147.0HP Electric Motor Electric Fuel System
# 543                               107.0HP Electric Motor Electric Fuel System
# 544                                                                 6.4 Liter
# 545                             400.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 546           5L V-8 gasoline direct injection, DOHC, variable valve control,
# 547                                                     3.2L H6 24V MPFI DOHC
# 548                             550.0HP 6.0L 12 Cylinder Engine Gasoline Fuel
# 549                              550.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 550                              420.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 551                              220.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 552                                                2.0L I4 16V GDI DOHC Turbo
# 553                              450.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 554                       360.0HP 6.0L 8 Cylinder Engine Flex Fuel Capability
# 555                                                     Dual Motor - Standard
# 556                                                                      2.5L
# 557                       188.0HP 2.0L 4 Cylinder Engine Plug-In Electric/Gas
# 558                              420.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 559                             250.0HP 3.2L V6 Cylinder Engine Gasoline Fuel
# 560                                                      2.5L I4 16V PDI DOHC
# 561                              577.0HP 5.5L 8 Cylinder Engine Gasoline Fuel
# 562                              429.0HP 4.7L 8 Cylinder Engine Gasoline Fuel
# 563                             290.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 564                                          6.7L I6 24V DDI OHV Turbo Diesel
# 565                             310.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 566                     453.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 567                                                      5.7L V8 16V MPFI OHV
# 568                              211.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 569                             304.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 570                              150.0HP 1.4L 4 Cylinder Engine Gasoline Fuel
# 571                              350.0HP 2.3L 4 Cylinder Engine Gasoline Fuel
# 572                              503.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 573                                                1.5L I3 12V PDI DOHC Turbo
# 574                                                     3.6L V6 24V MPFI DOHC
# 575                       247.0HP 2.0L 4 Cylinder Engine Plug-In Electric/Gas
# 576                                                2.0L I4 16V GDI DOHC Turbo
# 577                             300.0HP 3.7L V6 Cylinder Engine Gasoline Fuel
# 578                             365.0HP 3.3L V6 Cylinder Engine Gasoline Fuel
# 579                              383.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 580                             293.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 581                       139.0HP 1.6L 4 Cylinder Engine Plug-In Electric/Gas
# 582                             173.0HP 2.7L V6 Cylinder Engine Gasoline Fuel
# 583              389.0HP 3.0L Straight 6 Cylinder Engine Plug-In Electric/Gas
# 584                                                                 5.4 Liter
# 585                              567.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 586                             140.0HP 2.8L V6 Cylinder Engine Gasoline Fuel
# 587                             563.0HP 6.6L 12 Cylinder Engine Gasoline Fuel
# 588                             380.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 589                              221.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 590                                                     3.6L V6 24V MPFI DOHC
# 591                                                     3.6L V6 24V MPFI DOHC
# 592                     235.0HP 3.2L Straight 6 Cylinder Engine Gasoline Fuel
# 593                              200.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 594                              340.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 595                              325.0HP 6.0L 8 Cylinder Engine Gasoline Fuel
# 596                                                            4.0 Liter TFSI
# 597                             305.0HP 3.7L V6 Cylinder Engine Gasoline Fuel
# 598                              182.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# 599                              518.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 600                             293.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 601                     425.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 602                              630.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 603                             335.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 604                              567.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 605                              382.0HP 5.5L 8 Cylinder Engine Gasoline Fuel
# 606          HEMI 6.2L V-8 intercooled supercharger, premium unleaded, engine
# 607                              560.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 608                                                                 3.0 Liter
# 609                             375.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 610                              380.0HP 4.3L 8 Cylinder Engine Gasoline Fuel
# 611                             300.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 612                       381.0HP 5.7L 8 Cylinder Engine Flex Fuel Capability
# 613                              355.0HP 5.3L 8 Cylinder Engine Gasoline Fuel
# 614                                                     2.4L I4 16V MPFI SOHC
# ...
# 3805            335.0HP 3.0L V6 Cylinder Engine Gasoline/Mild Electric Hybrid
# 3806                            302.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 3807                                                    4.0L V6 24V MPFI DOHC
# 3808                             101.0HP 1.4L 4 Cylinder Engine Gasoline Fuel
# 3809                       191.0HP 2.5L 4 Cylinder Engine Gas/Electric Hybrid
# 3810                             300.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# 3811                                               2.0L I4 16V GDI DOHC Turbo
# 3812                     290.0HP 3.6L V6 Cylinder Engine Flex Fuel Capability
# 3813                              480.0HP Electric Motor Electric Fuel System
# 3814                             172.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# 3815                             278.0HP 4.3L 8 Cylinder Engine Gasoline Fuel
# 3816                                         6.7L V12 48V GDI DOHC Twin Turbo
# 3817                               475.0HP 6.7L 8 Cylinder Engine Diesel Fuel
# 3818                             400.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 3819                        350.0HP 3.4L Flat 6 Cylinder Engine Gasoline Fuel
# 3820                             252.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 3821                       200.0HP 2.5L 4 Cylinder Engine Gas/Electric Hybrid
# 3822                             200.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 3823                             170.0HP 1.8L 4 Cylinder Engine Gasoline Fuel
# 3824                        400.0HP 3.8L Flat 6 Cylinder Engine Gasoline Fuel
# 3825                      134.0HP 1.8L 4 Cylinder Engine Plug-In Electric/Gas
# 3826                               450.0HP 6.7L 8 Cylinder Engine Diesel Fuel
# 3827                             463.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 3828                        379.0HP 3.0L Flat 6 Cylinder Engine Gasoline Fuel
# 3829                             412.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 3830                                               2.0L I4 16V GDI DOHC Turbo
# 3831                                               1.4L I4 16V GDI DOHC Turbo
# 3832                    190.0HP 4.0L Straight 6 Cylinder Engine Gasoline Fuel
# 3833                             252.0HP 3.9L 8 Cylinder Engine Gasoline Fuel
# 3834                              563.0HP Electric Motor Electric Fuel System
# 3835                             362.0HP 5.4L 8 Cylinder Engine Gasoline Fuel
# 3836                             420.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 3837                    300.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 3838                        385.0HP 3.8L Flat 6 Cylinder Engine Gasoline Fuel
# 3839                             147.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 3840                             350.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 3841                             240.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 3842                                                     5.7L V8 16V MPFI OHV
# 3843                             281.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 3844                      385.0HP 6.2L 8 Cylinder Engine Flex Fuel Capability
# 3845                    300.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 3846                             255.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 3847                                                           2.0 Liter TFSI
# 3848                             300.0HP 2.3L 4 Cylinder Engine Gasoline Fuel
# 3849            335.0HP 3.0L V6 Cylinder Engine Gasoline/Mild Electric Hybrid
# 3850                             130.0HP 1.8L 4 Cylinder Engine Gasoline Fuel
# 3851                                               2.0L I4 16V GDI DOHC Turbo
# 3852                            400.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 3853            335.0HP 3.0L V6 Cylinder Engine Gasoline/Mild Electric Hybrid
# 3854                             490.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 3855                             179.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 3856                             241.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 3857                                                    3.5L V6 24V MPFI DOHC
# 3858                             460.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 3859                            365.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 3860                             355.0HP 5.3L 8 Cylinder Engine Gasoline Fuel
# 3861                             181.0HP 1.5L 3 Cylinder Engine Gasoline Fuel
# 3862                     283.0HP 3.6L V6 Cylinder Engine Flex Fuel Capability
# 3863                       139.0HP 1.6L 4 Cylinder Engine Gas/Electric Hybrid
# 3864                            308.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 3865                            505.0HP 2.9L V6 Cylinder Engine Gasoline Fuel
# 3866                             224.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 3867                               445.0HP 6.6L 8 Cylinder Engine Diesel Fuel
# 3868                             285.0HP 4.8L 8 Cylinder Engine Gasoline Fuel
# 3869                             429.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# 3870                      221.0HP 2.5L 4 Cylinder Engine Plug-In Electric/Gas
# 3871                                                    3.6L V6 24V MPFI DOHC
# 3872                      385.0HP 5.0L 8 Cylinder Engine Flex Fuel Capability
# 3873                             235.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 3874                            310.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 3875                             540.0HP 5.4L 8 Cylinder Engine Gasoline Fuel
# 3876                               440.0HP 6.7L 8 Cylinder Engine Diesel Fuel
# 3877                    184.0HP 2.5L Straight 6 Cylinder Engine Gasoline Fuel
# 3878                            602.0HP 5.2L 10 Cylinder Engine Gasoline Fuel
# 3879                             158.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# 3880                    300.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 3881                             455.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 3882                             140.0HP 1.8L 4 Cylinder Engine Gasoline Fuel
# 3883                             282.0HP 4.7L 8 Cylinder Engine Gasoline Fuel
# 3884                             383.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 3885                             449.0HP 4.7L 8 Cylinder Engine Gasoline Fuel
# 3886                                                            2.0 Liter TSI
# 3887                             381.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 3888                             420.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 3889                             170.0HP 1.8L 4 Cylinder Engine Gasoline Fuel
# 3890                             182.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 3891                                                          2.0 Liter Turbo
# 3892                            365.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 3893                             176.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 3894                            270.0HP 4.0L V6 Cylinder Engine Gasoline Fuel
# 3895                             362.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# 3896                              455.0HP Electric Motor Electric Fuel System
# 3897                    300.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 3898                            250.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 3899                            310.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 3900                             248.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 3901                                                     2.5L I4 16V GDI DOHC
# 3902                             555.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 3903                             248.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 3904                            333.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 3905                            545.0HP 3.8L V6 Cylinder Engine Gasoline Fuel
# 3906                              425.0HP Electric Motor Electric Fuel System
# 3907                            200.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 3908                                                                 Electric
# 3909                             200.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 3910                            270.0HP 4.0L V6 Cylinder Engine Gasoline Fuel
# 3911                                               2.0L I4 16V GDI DOHC Turbo
# 3912                    300.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 3913                              518.0HP Electric Motor Electric Fuel System
# 3914                             301.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# 3915                             390.0HP 6.0L 8 Cylinder Engine Gasoline Fuel
# 3916                             227.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 3917                             170.0HP 2.5L 5 Cylinder Engine Gasoline Fuel
# 3918                                                                        –
# 3919             201.0HP 2.0L 4 Cylinder Engine Gasoline/Mild Electric Hybrid
# 3920                            400.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 3921                             310.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 3922                                                                        –
# 3923                             382.0HP 5.5L 8 Cylinder Engine Gasoline Fuel
# 3924                             241.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 3925                                          4.4L V8 32V GDI DOHC Twin Turbo
# 3926                            215.0HP 3.2L V6 Cylinder Engine Gasoline Fuel
# 3927                            310.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 3928                            288.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 3929                            335.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 3930                            242.0HP 3.3L V6 Cylinder Engine Gasoline Fuel
# 3931                                               2.5L I4 16V GDI DOHC Turbo
# 3932                              778.0HP Electric Motor Electric Fuel System
# 3933                            285.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 3934                            245.0HP 4.0L V6 Cylinder Engine Gasoline Fuel
# 3935                             355.0HP 5.3L 8 Cylinder Engine Gasoline Fuel
# 3936                             290.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 3937                             355.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 3938                             248.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 3939                            276.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 3940                             188.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 3941                             152.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 3942                             400.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 3943                               211.0HP 2.0L 4 Cylinder Engine Diesel Fuel
# 3944                             174.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 3945                             181.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 3946                             170.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 3947                       134.0HP 1.8L 4 Cylinder Engine Gas/Electric Hybrid
# 3948                            328.0HP 3.7L V6 Cylinder Engine Gasoline Fuel
# 3949                             252.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 3950                             182.0HP 2.5L 4 Cylinder Engine Gasoline Fuel
# 3951                                                     2.5L I4 16V GDI DOHC
# 3952                                                                        –
# 3953                      169.0HP 2.5L 4 Cylinder Engine Flex Fuel Capability
# 3954                             449.0HP 4.7L 8 Cylinder Engine Gasoline Fuel
# 3955                             403.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 3956                             136.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 3957                            204.0HP 2.5L V6 Cylinder Engine Gasoline Fuel
# 3958                            295.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 3959                             490.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 3960                            285.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 3961                                                                 Electric
# 3962                                                    4.0L V6 24V MPFI DOHC
# 3963                            265.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 3964                        379.0HP 3.0L Flat 6 Cylinder Engine Gasoline Fuel
# 3965                                          2.7L V6 24V PDI DOHC Twin Turbo
# 3966                    382.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 3967                       134.0HP 1.8L 4 Cylinder Engine Gas/Electric Hybrid
# 3968                            375.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 3969                             310.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# 3970                             245.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 3971                                               2.0L I4 16V GDI DOHC Turbo
# 3972                            329.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 3973                     283.0HP 3.6L V6 Cylinder Engine Flex Fuel Capability
# 3974                             136.0HP 1.8L 4 Cylinder Engine Gasoline Fuel
# 3975                            375.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 3976                             385.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 3977                             270.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 3978                               400.0HP 6.7L 8 Cylinder Engine Diesel Fuel
# 3979                            340.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 3980                        400.0HP 3.8L Flat 6 Cylinder Engine Gasoline Fuel
# 3981                            315.0HP 2.7L V6 Cylinder Engine Gasoline Fuel
# 3982                             150.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 3983                             166.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 3984                                                                        –
# 3985                             143.0HP 1.8L 4 Cylinder Engine Gasoline Fuel
# 3986                              188.0HP 3.0L V6 Cylinder Engine Diesel Fuel
# 3987                             240.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 3988                            240.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 3989                             455.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 3990                            325.0HP 2.7L V6 Cylinder Engine Gasoline Fuel
# 3991                                          4.0L V8 32V GDI DOHC Twin Turbo
# 3992                             310.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# 3993                        443.0HP 3.0L Flat 6 Cylinder Engine Gasoline Fuel
# 3994                             617.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 3995                       134.0HP 1.8L 4 Cylinder Engine Gas/Electric Hybrid
# 3996                            420.0HP 5.9L 12 Cylinder Engine Gasoline Fuel
# 3997                            305.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 3998                        350.0HP 3.4L Flat 6 Cylinder Engine Gasoline Fuel
# 3999                    335.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel
# 4000                             260.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# 4001                            283.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 4002             603.0HP 4.0L 8 Cylinder Engine Gasoline/Mild Electric Hybrid
# 4003                             241.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 4004                                         6.0L W12 48V PDI DOHC Twin Turbo
# 4005                            349.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 4006                                                                 Electric
# 4007                            450.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 4008                             248.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# Name: engine, dtype: object

# %%
# Extract horsepower (e.g., "354.0HP" → 354.0)
df['horsepower'] = df['engine'].str.extract(r'(\d+\.?\d*)\s*HP', expand=False).astype(float)

# Extract engine capacity (e.g., "3.5L" or "3 L" → 3.5)
df['engine_capacity'] = df['engine'].str.extract(r'(\d+\.\d+|\d+)\s*[lL]', expand=False).astype(float)

# %%
df[['engine', 'horsepower', 'engine_capacity']].head(10)
# Out:
#                                                  engine  horsepower  \
# 0  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capability       300.0
# 1                                  3.8L V6 24V GDI DOHC         NaN
# 2                                        3.5 Liter DOHC         NaN
# 3   354.0HP 3.5L V6 Cylinder Engine Gas/Electric Hybrid       354.0
# 4                            2.0L I4 16V GDI DOHC Turbo         NaN
# 5                                             2.4 Liter         NaN
# 6          292.0HP 2.0L 4 Cylinder Engine Gasoline Fuel       292.0
# 7          282.0HP 4.4L 8 Cylinder Engine Gasoline Fuel       282.0
# 8         311.0HP 3.5L V6 Cylinder Engine Gasoline Fuel       311.0
# 9           534.0HP Electric Motor Electric Fuel System       534.0
#
#    engine_capacity
# 0              3.7
# 1              3.8
# 2              3.5
# 3              3.5
# 4              2.0
# 5              2.4
# 6              2.0
# 7              4.4
# 8              3.5
# 9              NaN

# %% [markdown]
# Some vehicles are fully electric, while others are gas/electric hybrids.

# %%
# Detect electric and hybrid vehicles

df['is_electric'] = df['engine'].str.contains('Electric', case=False, na=False).astype(int)
df['is_hybrid'] = df['engine'].str.contains('Hybrid', case=False, na=False).astype(int)

# %%
# Fill missing horsepower by brand median
df['horsepower'] = df.groupby('brand')['horsepower'].transform(lambda x: x.fillna(x.median()))

# Fill missing engine_capacity by brand median
df['engine_capacity'] = df.groupby('brand')['engine_capacity'].transform(lambda x: x.fillna(x.median()))

# This respects brand-specific power characteristics — e.g., BMW cars typically have higher engine capacity than Suzuki.

# %%
# For fully electric (not hybrid) vehicles, set engine_capacity = 0
df.loc[(df['is_electric'] == 1) & (df['is_hybrid'] == 0), 'engine_capacity'] = 0

# %%
# Fill any remaining missing engine_capacity using the median of non-electric cars
non_electric_median = df.loc[df['is_electric'] == 0, 'engine_capacity'].median()
df['engine_capacity'].fillna(non_electric_median, inplace=True)

# %%
df[['horsepower', 'engine_capacity', 'is_electric', 'is_hybrid']].isnull().sum()
# Out:
# horsepower         2
# engine_capacity    0
# is_electric        0
# is_hybrid          0
# dtype: int64

# %%
df['horsepower'] = df['horsepower'].fillna(df['horsepower'].median())

# %%
df[['horsepower', 'engine_capacity', 'is_electric', 'is_hybrid']].isnull().sum()
# Out:
# horsepower         0
# engine_capacity    0
# is_electric        0
# is_hybrid          0
# dtype: int64

# %%
df.head()
# Out:
#       brand                            model  model_year   milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51000.0
# 1   Hyundai                     Palisade SEL        2021  34742.0
# 2     Lexus                    RX 350 RX 350        2022  22372.0
# 3  INFINITI                 Q50 Hybrid Sport        2015  88900.0
# 4      Audi        Q3 45 S line Premium Plus        2021   9835.0
#
#        fuel_type                                                engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capability
# 1       Gasoline                                  3.8L V6 24V GDI DOHC
# 2       Gasoline                                        3.5 Liter DOHC
# 3         Hybrid   354.0HP 3.5L V6 Cylinder Engine Gas/Electric Hybrid
# 4       Gasoline                            2.0L I4 16V GDI DOHC Turbo
#
#         transmission                 ext_col int_col  \
# 0        6-Speed A/T                   Black   Black
# 1  8-Speed Automatic         Moonlight Cloud    Gray
# 2          Automatic                    Blue   Black
# 3        7-Speed A/T                   Black   Black
# 4  8-Speed Automatic  Glacier White Metallic   Black
#
#                                  accident    price  horsepower  \
# 0  At least 1 accident or damage reported  10300.0       300.0
# 1  At least 1 accident or damage reported  38005.0       240.0
# 2                           None reported  54598.0       301.0
# 3                           None reported  15500.0       354.0
# 4                           None reported  34999.0       333.0
#
#    engine_capacity  is_electric  is_hybrid
# 0              3.7            0          0
# 1              3.8            0          0
# 2              3.5            0          0
# 3              3.5            1          1
# 4              2.0            0          0

# %%
# New feature -> Car Age

from datetime import datetime
current_year = datetime.now().year

df['car_age'] = current_year - df['model_year']
